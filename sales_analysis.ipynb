# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('/content/Sales Data.csv')
df.head()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001   12.0
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   12.0
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001   12.0
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   12.0
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301   12.0
#
#      Sales            City  Hour
# 0  1700.00   New York City   0.0
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0       Order ID  Quantity Ordered    Price Each  \
# count  34612.000000   34612.000000      34612.000000  34612.000000
# mean   10410.463770  272490.536201          1.125939    183.949643
# std     7218.270737   56989.610578          0.444811    332.093099
# min        0.000000  176558.000000          1.000000      2.990000
# 25%     4348.000000  184855.750000          1.000000     11.950000
# 50%     8695.500000  303029.500000          1.000000     14.950000
# 75%    16416.250000  311358.250000          1.000000    150.000000
# max    25116.000000  319670.000000          7.000000   1700.000000
#
#               Month         Sales          Hour
# count  34611.000000  34611.000000  34611.000000
# mean       9.765653    185.059460     14.388865
# std        3.593303    332.592918      5.408425
# min        1.000000      2.990000      0.000000
# 25%        4.000000     11.950000     11.000000
# 50%       12.000000     14.950000     15.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34612 entries, 0 to 34611
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        34612 non-null  int64
#  1   Order ID          34612 non-null  int64
#  2   Product           34612 non-null  object
#  3   Quantity Ordered  34612 non-null  int64
#  4   Price Each        34612 non-null  float64
#  5   Order Date        34611 non-null  object
#  6   Purchase Address  34611 non-null  object
#  7   Month             34611 non-null  float64
#  8   Sales             34611 non-null  float64
#  9   City              34611 non-null  object
#  10  Hour              34611 non-null  float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 2.9+ MB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# Sales               0
# City                0
# Hour                0
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# Sales               0
# City                0
# Hour                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Check if the dtype of each column is 'object'
categorical_columns = [column for column in X.columns if X[column].dtype.name == 'object']

for column in categorical_columns:
    X[column] = le.fit_transform(X[column])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a4b7ecdb595c> in <cell line: 6>()
#       4
#       5 # Check if the dtype of each column is 'object'
# ----> 6 categorical_columns = [column for column in X.columns if X[column].dtype.name == 'object']
#       7
#       8 for column in categorical_columns:
#
# NameError: name 'X' is not defined

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5), layout='constrained')
graph = sns.countplot(x=df['City'], ax=ax)
plt.xticks(rotation=35)
plt.show()

# %%
"""sns.countplot(x=df['Purchase Address'])
plt.show()"""

# %%
sns.displot(df['Sales'],kind="kde")

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5), layout='constrained')
graph = sns.countplot(x=df['Month'], ax=ax)
plt.xticks(rotation=35)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5), )
graph = sns.countplot(x=df['Hour'], ax=ax , color=" ", )


plt.xticks(rotation=35)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10), layout='constrained')
graph = sns.countplot(x=df['Product'], ax=ax)
plt.xticks(rotation=50)
plt.show()
